# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

from sklearn import metrics
import seaborn as sns

import  matplotlib.pyplot as plt
import numpy as np

(X_train, Y_train), (X_test, Y_test) = mnist.load_data() #acá estamos cargando la información

Y_train= to_categorical(np.array(Y_train))
Y_test = to_categorical(np.array(Y_test))

IMG_SHAPE = X_train[0].shape
TARGET_CNT= len(Y_train[0])

print(IMG_SHAPE, TARGET_CNT)
plt.imshow(X_train[0, :,:], cmap='gray')

# normalización para tener datos entre 0 y 1
X_train = X_train / 255
X_test  = X_test  / 255
# Out:
# (28, 28) 10

# %%
F = 64#cantidad de filtros -> cantidad de matrices de conversión que usa
K = 3#tamaño del kernel -> tamaño de los filtros cuadrados, si dice 3 entonces será de 3x3
S = 1#valor del stride -> cuántos píxeles se desplaza en cada paso
FUN = "sigmoid"#función de activación de la capa de convolución

model = Sequential() #digo de qué forma voy a especificar las capas y neuronas

model = Sequential()
model.add(Input(shape=(28, 28, 1)))
model.add(Conv2D(F, kernel_size=K, strides=(S,S), activation=FUN))
model.add(MaxPooling2D(pool_size=(2,2))) #capa opcional para achicar las imágenes resultantes, donde se queda con el max pixel de cada 4
model.add(Flatten())
model.add(Dense(10,activation='softmax'))
es = EarlyStopping(monitor='val_accuracy', patience=5, min_delta=0.001)#para terminar si la precisión de validación decae y así no overfitear

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'] )
model.summary()
# Out:
# Model: "sequential_57"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_28 (Conv2D)                   │ (None, 26, 26, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_18 (MaxPooling2D)      │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_27 (Flatten)                 │ (None, 10816)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 10)                  │         108,170 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 108,810 (425.04 KB)
#  Trainable params: 108,810 (425.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#!pip install livelossplot --quiet

# %%
LOTES  = 32
EPOCAS = 25

from livelossplot import PlotLossesKeras

H = model.fit(x = X_train, y = Y_train, batch_size = LOTES,
validation_data = (X_test, Y_test), epochs=EPOCAS, callbacks=[es]) 

# hago gráfico
fig, axs = plt.subplots(1,2, figsize=(20,6))
plt.figure()
axs[0].plot(H.history["loss"], label="train_loss")
axs[0].plot(H.history["val_loss"], label="val_loss")
axs[1].plot(H.history["accuracy"], label="train_acc")
axs[1].plot(H.history["val_accuracy"], label="val_acc")


print (X_train.shape)
pred = model.predict(X_train)

cm = metrics.confusion_matrix(np.argmax(Y_train, axis=1), np.argmax(pred, axis=1))
plt.figure()
sns.heatmap(cm, square=True,  annot=True, fmt='d')


# %% evalua el modelo para entrenamiento y testeo
pred = model.evaluate(X_train, Y_train, verbose=0)
print("\nEfectividad del modelo con datos de entrenamiento: %6.2f%%" % (pred[1]*100))

# evalua el modelo con los datos de validacion
pred = model.evaluate(X_test, Y_test, verbose=0)
print("Efectividad del modelo con datos de Prueba.......: %6.2f%%" % (pred[1]*100))
# Out:
# Epoch 1/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 31s 16ms/step - accuracy: 0.5620 - loss: 1.4872 - val_accuracy: 0.8760 - val_loss: 0.4261
# Epoch 2/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8814 - loss: 0.4092 - val_accuracy: 0.9288 - val_loss: 0.2636
# Epoch 3/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9080 - loss: 0.3246 - val_accuracy: 0.9514 - val_loss: 0.1759
# Epoch 4/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9322 - loss: 0.2358 - val_accuracy: 0.9485 - val_loss: 0.1716
# Epoch 5/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9493 - loss: 0.1695 - val_accuracy: 0.9454 - val_loss: 0.1957
# Epoch 6/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9567 - loss: 0.1456 - val_accuracy: 0.9693 - val_loss: 0.0998
# Epoch 7/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9632 - loss: 0.1234 - val_accuracy: 0.9720 - val_loss: 0.0970
# Epoch 8/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9704 - loss: 0.1018 - val_accuracy: 0.9674 - val_loss: 0.1077
# Epoch 9/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9739 - loss: 0.0896 - val_accuracy: 0.9744 - val_loss: 0.0921
# Epoch 10/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9758 - loss: 0.0812 - val_accuracy: 0.9644 - val_loss: 0.1321
# Epoch 11/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9762 - loss: 0.0779 - val_accuracy: 0.9783 - val_loss: 0.0807
# Epoch 12/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9801 - loss: 0.0648 - val_accuracy: 0.9699 - val_loss: 0.1076
# Epoch 13/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9818 - loss: 0.0560 - val_accuracy: 0.9799 - val_loss: 0.0706
# Epoch 14/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9838 - loss: 0.0520 - val_accuracy: 0.9791 - val_loss: 0.0762
# Epoch 15/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9855 - loss: 0.0489 - val_accuracy: 0.9757 - val_loss: 0.0927
# Epoch 16/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9852 - loss: 0.0487 - val_accuracy: 0.9773 - val_loss: 0.0809
# Epoch 17/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 32s 17ms/step - accuracy: 0.9869 - loss: 0.0411 - val_accuracy: 0.9816 - val_loss: 0.0659
# Epoch 18/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 31s 16ms/step - accuracy: 0.9880 - loss: 0.0375 - val_accuracy: 0.9788 - val_loss: 0.0795
# Epoch 19/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9885 - loss: 0.0363 - val_accuracy: 0.9813 - val_loss: 0.0725
# Epoch 20/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 31s 16ms/step - accuracy: 0.9885 - loss: 0.0358 - val_accuracy: 0.9788 - val_loss: 0.0824
# Epoch 21/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9899 - loss: 0.0304 - val_accuracy: 0.9806 - val_loss: 0.0684
# Epoch 22/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 31s 16ms/step - accuracy: 0.9897 - loss: 0.0298 - val_accuracy: 0.9799 - val_loss: 0.0775
# (60000, 28, 28)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step
#
# Efectividad del modelo con datos de entrenamiento:  99.20%
# Efectividad del modelo con datos de Prueba.......:  97.99%

# %% [markdown]
# # Resultados (max 25 épocas)
#
# | Cant. de filtros | Tamaño del kernel o filtro | Stride | Función de activación | Max Pooling con filtro de tamaño 2x2 y stride=2 | Total de parámetros | Épocas | Accuracy en Train | Accuracy en Test |
# |------------------|----------------------------|--------|-----------------------|-------------------------------------------------|---------------------|--------|-------------------|------------------|
# | 4                | 3x3                        | 1      | ReLU                  | Sí                                              |        6810|   19     |      98.56             |       97.49           |
# | 16               | 3x3                        | 1      | ReLU                  | Sí                                              |        27210             |    11    |       99.27            |        98.19          |
# | 64               | 3x3                        | 1      | ReLU                  | Sí                                              |        108810             |     12   |        99.90           |       98.48           |
# | 4                | 7x7                        | 1      | ReLU                  | Sí                                              |        5050             |     13   |        98.85           |        98.08          |
# | 16               | 7x7                        | 1      | ReLU                  | Sí                                              |       20170              |     14   |         99.77          |         98.78         |
# | 64               | 7x7                        | 1      | ReLU                  | Sí                                              |        80650             |     9   |           99.69        |            98.77      |
# | 64               | 3x3                        | 1      | ReLU                  | No                                              |       433290              |     11   |           99.86        |            98.13      |
# | 64               | 3x3                        | 2      | ReLU                  | No                                              |      108810               |     11  |              99.63    |              97.84    |
# | 64               | 3x3                        | 3      | ReLU                  | No                                              |      52490               |      12 |              98.86    |              97.39    |
# | 64               | 3x3                        | 1      | TanH                  | Sí                                              |     108810                |      10  |             99.34      |            97.67      |
# | 64               | 3x3                        | 1      | Sigmoide              | Sí                                              |      108810               |      22  |             99.2      |             97.99     |

# %% [markdown]
# # conclusiones
#
# Usar relu acelera el proceso por tener una derivada sencilla de calcular. Ante una red muy profunda se va a notar que ReLu es mejor, ya que en el backpropagation no se reduce tanto el error, lo cual acelera el proceso de aprendizaje
#
# Usar pooling no afecta practicamente en los resultados y nos permite hacer más rápido el entrenamiento
#
# No es necesario una gran cantidad de filtros ni de matriz para poder resolver este problema

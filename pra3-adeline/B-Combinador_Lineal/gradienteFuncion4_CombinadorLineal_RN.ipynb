# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time
#from matplotlib import pyplot as plt
from matplotlib import pylab as plt
from IPython import display

from grafica import *
from ClassNeuronaLineal import NeuronaLineal

# %%
X = np.array([2, 1, -1]).reshape(-1,1)
Y = np.array([3, 1, -3])
print(X)
print(Y)
# Out:
# [[ 2]
#  [ 1]
#  [-1]]
# [ 3  1 -3]

# %%
nl = NeuronaLineal(alpha=0.31, n_iter=30, cotaE=0.001, draw=1, title=['X', 'Y'])
# --- utilice random_state=None para que los pesos se inicializacen en forma aleatoria --
nl.fit(X, Y)

# %%
print("W = ", nl.w_)
print("b = ", nl.b_)
# Out:
# W =  [1.99891306]
# b =  [-0.99776379]

# %%
plt.plot(range(1, len(nl.errors_) + 1), nl.errors_, marker='o')
plt.xlabel('Iteraciones')
plt.ylabel('Cantidad de actualizaciones')
plt.show()

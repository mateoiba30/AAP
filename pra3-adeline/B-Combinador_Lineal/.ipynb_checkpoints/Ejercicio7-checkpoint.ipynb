# %% [markdown]
# # a)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time
#from matplotlib import pyplot as plt
from matplotlib import pylab as plt
from IPython import display
from sklearn import model_selection,preprocessing, metrics

from grafica import *
from ClassNeuronaLineal import NeuronaLineal

# %%
datos= pd.read_csv('../../Datos/automobile-simple.csv')
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   make          205 non-null    object
#  1   fuel-type     205 non-null    object
#  2   num-of-doors  203 non-null    object
#  3   body-style    205 non-null    object
#  4   curb-weight   205 non-null    int64
#  5   engine-size   205 non-null    int64
#  6   horsepower    203 non-null    float64
#  7   city-mpg      205 non-null    int64
#  8   highway-mpg   205 non-null    int64
#  9   price         201 non-null    float64
#  10  volume        205 non-null    float64
#  11  eco-rating    205 non-null    float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 19.3+ KB

# %%
print(datos.sample(15))
print(datos['price'].isna().sum())
# Out:
#            make fuel-type num-of-doors   body-style  curb-weight  engine-size  \
# 174      toyota    diesel         four        sedan         2480          110
# 32        honda       gas          two    hatchback         1837           79
# 50        mazda       gas          two    hatchback         1890           91
# 78   mitsubishi       gas          two    hatchback         2004           92
# 27        dodge       gas          NaN        sedan         2191           98
# 91       nissan       gas          two        sedan         1918           97
# 46        isuzu       gas          two    hatchback         2734          119
# 198       volvo       gas         four        sedan         3045          130
# 177      toyota       gas         four    hatchback         2458          122
# 47       jaguar       gas         four        sedan         4066          258
# 48       jaguar       gas         four        sedan         4066          258
# 4          audi       gas         four        sedan         2824          136
# 203       volvo    diesel         four        sedan         3217          145
# 128     porsche       gas          two  convertible         2800          194
# 18    chevrolet       gas          two    hatchback         1488           61
#
#      horsepower  city-mpg  highway-mpg    price      volume  eco-rating
# 174        73.0        30           33  10698.0  641089.260   45.650577
# 32         60.0        38           42   5399.0  504960.000   64.267559
# 50         68.0        30           31   5195.0  552589.302   49.885101
# 78         68.0        31           38   6669.0  514610.096   53.980390
# 27        102.0        24           30   8558.0  507808.444   39.928042
# 91         69.0        31           37   6649.0  574764.630   56.138344
# 46         90.0        24           29  11048.0  578430.928   37.703670
# 198       162.0        17           22  18420.0  713029.632   27.780359
# 177        92.0        27           32  11248.0  629411.860   45.720702
# 47        176.0        15           19  32250.0  733506.048   19.940440
# 48        176.0        15           19  35550.0  733506.048   19.940440
# 4         115.0        18           22  17450.0  636734.832   27.997459
# 203       106.0        26           27  22470.0  721961.760   35.073342
# 128       207.0        17           25  37028.0  566490.600   28.030665
# 18         48.0        47           53   5151.0  452643.156   82.722718
# 4

# %%
price_promedio = datos["price"].mean()
print(price_promedio)
# Out:
# 13207.129353233831

# %%
datos["price"] = datos["price"].fillna(price_promedio)
print(datos['price'].isna().sum())
# Out:
# 0

# %%
T = np.array(datos['price'])
X = np.array(datos['engine-size'])
X = X.reshape(-1,1)
T = T.reshape(-1,1)

# %%
normalizar = 1
if normalizar:
    normalizador= preprocessing.MinMaxScaler()
    #normalizador= preprocessing.StandardScaler() #media y desvío
    X = normalizador.fit_transform(X)
    T = normalizador.fit_transform(T)
    
print(X)
print(T)

# %%
nl = NeuronaLineal(alpha=0.02, n_iter=50, cotaE=10e-05, draw=1, title=['X: engine size', 'Y: price'])
# --- utilice random_state=None para que los pesos se inicializacen en forma aleatoria --
nl.fit(X, T)

# %%
print("W = ", nl.w_)
print("b = ", nl.b_)
# Out:
# W =  [1.05012939]
# b =  [-0.06474841]

# %%
plt.plot(range(1, len(nl.errors_) + 1), nl.errors_, marker='o')
plt.xlabel('Iteraciones')
plt.ylabel('Cantidad de actualizaciones')
plt.show()

# %% [markdown]
# # Conclusiones:
# - sin normalizar los números de actualizaciones crecían a medida que avanzábamos en las iteraciones. La recta obtenida no fue representativa
# - al normalizar entre 0 y 1 la gráfica fue más o menos representativa y cada vez el modelo hacía menos actualizaciones. Parece que no modifica bien la pendiente, solo la ordenada al origen
# - al normalizar con la media y desvío parece que tuve los mejores resultados

# %%
Y = nl.predict(X)

# Calculamos los aciertos
aciertos = sum(Y == T)

# Calculamos la precisión
precision = 100 * aciertos / len(T)  # Usa len(T) para el número de muestras

# Mostramos los resultados
print("%% de aciertos = %.2f %%" % (precision))

# Verificamos el número de iteraciones
if hasattr(nl, 'errors'):
    print("Cantidad de iteraciones: ", len(nl.errors))
else:
    print("El modelo no tiene un atributo 'errors'")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 Y = nl.predict(X)
#       3 # Calculamos los aciertos
#       4 aciertos = sum(Y == T)
#
# File ~\Documents\1-uni\2024\cuatri2\aap\pra\pra3-adeline\B-Combinador_Lineal\ClassNeuronaLineal.py:98, in NeuronaLineal.predict(self, X)
#      96 def predict(self, X):
#      97     """Return class label after unit step"""
# ---> 98     return self.net_input(X)
#
# File ~\Documents\1-uni\2024\cuatri2\aap\pra\pra3-adeline\B-Combinador_Lineal\ClassNeuronaLineal.py:94, in NeuronaLineal.net_input(self, X)
#      92 def net_input(self, X):
#      93     """Calculate net input"""
# ---> 94     return np.dot(X, self.w_) + self.b_
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# ValueError: shapes (205,) and (1,) not aligned: 205 (dim 0) != 1 (dim 0)

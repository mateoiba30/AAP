# %% [markdown]
# # De los voy a indicar el error cuadrático promedio de cada modelo:
# w; b; error
# - -2, 500,

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time
#from matplotlib import pyplot as plt
from matplotlib import pylab as plt
from IPython import display

from grafica import *
from ClassNeuronaLineal import NeuronaLineal

# %%
datos= pd.read_csv('../../Datos/CCPP.csv')
T = np.array(datos['PE'])
X = np.array(datos['AT'])
X = X.reshape(-1,1)
print(X)
print(T)
# Out:
# [[14.96]
#  [25.18]
#  [ 5.11]
#  ...
#  [31.32]
#  [24.48]
#  [21.6 ]]
# [463.26 444.37 488.56 ... 429.57 435.74 453.28]

# %%
nl = NeuronaLineal(alpha=0.0001, n_iter=50, cotaE=10e-06, draw=1, title=['X: AT', 'Y: PE'])
# --- utilice random_state=None para que los pesos se inicializacen en forma aleatoria --
nl.fit(X, T)

# %%
print("W = ", nl.w_)
print("b = ", nl.b_)
# Out:
# W =  [-2.15650335]
# b =  495.7857238405534

# %%
plt.plot(range(1, len(nl.errors_) + 1), nl.errors_, marker='o')
plt.xlabel('Iteraciones')
plt.ylabel('Cantidad de actualizaciones')
plt.show()

# %% [markdown]
# # Respuesta:
# la opción con menor error cuadrático es la opción e)
